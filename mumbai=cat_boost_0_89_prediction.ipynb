# %% [markdown]
# <a href="https://colab.research.google.com/github/rohansejwal-netizen/Price-Prediction/blob/main/mumbai%3Dcat_boost_0_89_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
file_path="/content/UPDATED DATA"
main=pd.read_csv(file_path)

# %%
main['Floor No'].replace('Upper Basement',np.nan,inplace=True)
main['Floor No'].replace('Lower Basement',np.nan,inplace=True)
main['Floor No'].replace('Ground',0,inplace=True)
main.dropna(subset=['Floor No'],inplace=True)
# Out:
# /tmp/ipython-input-328279332.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   main['Floor No'].replace('Upper Basement',np.nan,inplace=True)
# /tmp/ipython-input-328279332.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
main['furnished Type'].replace('NO IDEA',np.nan,inplace=True)
main.dropna(subset=['furnished Type'],inplace=True)
# Out:
# /tmp/ipython-input-1744672434.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   main['furnished Type'].replace('NO IDEA',np.nan,inplace=True)

# %%
main["Floor No"].unique()
# Out:
# array(['5', '20', '18', '8', '16', '1', '4', '10', '9', '2', '11', '21',
#        '7', '3', 'Visit & See', '12', '6', '17', '15', 0, '14', '13',
#        '19', '27', '26', '29', '25', '24', '23', '35', '40', '34', '28',
#        '32', '30', '22', '38', '33', '45', '47', '60', '37', '31', '93',
#        '36', '39', '46', '42', '43', '50', '48', '61', '49', '51', '54',
#        '55', '62', '41', '57', '56', '44', '71', '52', '65', '58', '59',
#        '64', '63', '66'], dtype=object)

# %%
main['Floor No'].replace({
    'Visit & See': np.nan
},inplace=True)
# Out:
# /tmp/ipython-input-1692829512.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   main['Floor No'].replace({

# %%
main["Units Available"].replace('Not Mentioned',np.nan,inplace=True)
# Out:
# /tmp/ipython-input-319591635.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   main["Units Available"].replace('Not Mentioned',np.nan,inplace=True)

# %%
main.drop("Units Available",axis=1,inplace=True)

# %%
main.drop("Price (English)",axis=1,inplace=True)

# %%
main.drop('Booking Amount',axis=1,inplace=True)

# %%
main['Property Uniqueness'].replace('NOT AVAILABLE',np.nan,inplace=True)
# Out:
# /tmp/ipython-input-2300835814.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   main['Property Uniqueness'].replace('NOT AVAILABLE',np.nan,inplace=True)

# %%
main["Developer"].replace('Not Mentioned',np.nan,inplace=True)
# Out:
# /tmp/ipython-input-2899578594.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   main["Developer"].replace('Not Mentioned',np.nan,inplace=True)

# %%
main['Approved Authority Name'].replace('Not Mentioned',np.nan,inplace=True)
# Out:
# /tmp/ipython-input-864077037.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   main['Approved Authority Name'].replace('Not Mentioned',np.nan,inplace=True)

# %%
main['balconies'].replace('NO BAlCONY',np.nan,inplace=True)
# Out:
# /tmp/ipython-input-492206805.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   main['balconies'].replace('NO BAlCONY',np.nan,inplace=True)

# %%
main.drop('Price_in_Rupees',axis=1,inplace=True)

# %%
main.drop('Unnamed: 0',axis=1,inplace=True)

# %%
main.dropna(subset=['Developer'],inplace=True)

# %%
main.isna().sum()
# Out:
# ID                            0
# Floor No                    500
# Commercial                    0
# Developer                     0
# Approved Authority Name    3052
# sqft Price                    0
# Area Name                     0
# Property Uniqueness        4306
# Society                       0
# Facing                        0
# Type of Property              0
# City                          0
# furnished Type                0
# Location                     55
# balconies                  3506
# Sea facing                    0
# Price                         0
# dtype: int64

# %%
main.drop('Property Uniqueness',axis=1,inplace=True)

# %%
main.isna().sum()
# Out:
# ID                            0
# Floor No                    500
# Commercial                    0
# Developer                     0
# Approved Authority Name    3052
# sqft Price                    0
# Area Name                     0
# Society                       0
# Facing                        0
# Type of Property              0
# City                          0
# furnished Type                0
# Location                     55
# balconies                  3506
# Sea facing                    0
# Price                         0
# dtype: int64

# %%
main['balconies'].unique()
# Out:
# array([nan, '3.0', '1.0', '2.0', '4.0', '5.0', '6.0', '7.0', '8.0'],
#       dtype=object)

# %%
main.dropna(subset=['balconies'],inplace=True)

# %%
main.drop('Approved Authority Name',axis=1,inplace=True)

# %%
main.isna().sum()
# Out:
# ID                   0
# Floor No            79
# Commercial           0
# Developer            0
# sqft Price           0
# Area Name            0
# Society              0
# Facing               0
# Type of Property     0
# City                 0
# furnished Type       0
# Location            25
# balconies            0
# Sea facing           0
# Price                0
# dtype: int64

# %%
main.dropna(subset=['Location'],inplace=True)

# %%
main.isna().sum()
# Out:
# ID                   0
# Floor No            66
# Commercial           0
# Developer            0
# sqft Price           0
# Area Name            0
# Society              0
# Facing               0
# Type of Property     0
# City                 0
# furnished Type       0
# Location             0
# balconies            0
# Sea facing           0
# Price                0
# dtype: int64

# %%
main['SQFT_AREA']=main['Price']/main['sqft Price ']

# %%
# Function to calculate outliers using IQR
def count_outliers_iqr(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = df[(df[column] < lower_bound) | (df[column] > upper_bound)]
    return len(outliers)

# Count outliers for 'REG_FEE' and 'SALES_PRICE'
outliers_Price = count_outliers_iqr(main, 'Price')
outliers_sqft_Price = count_outliers_iqr(main, 'sqft Price ')

print(f"Number of outliers in 'Price': {outliers_Price}")
print(f"Number of outliers in 'sqft Price': {outliers_sqft_Price}")
# Out:
# Number of outliers in 'Price': 318
# Number of outliers in 'sqft Price': 166

# %%
main["sqft Price "].max()
# Out:
# 89774

# %%
main
# Out:
#           ID Floor No Commercial           Developer  sqft Price   \
# 3      12682        5          N       Birla Estates         8571
# 5      12680       16          N       Tycoons Group         6157
# 8      12677       16          N   Godrej Properties         5826
# 14     12671       16          N     Gurukrupa Group         6763
# 17     12668        9          N     Gurukrupa Group         7608
# ...      ...      ...        ...                 ...          ...
# 12662     23        4          N      Sheth Creators        17049
# 12669     16       19          Y  Oberoi Realty Ltd.        40840
# 12671     14       12          N         Nahar Group        28280
# 12681      4       10          N      Kalpataru Ltd.        22529
# 12682      3        5          N      Kalpataru Ltd.        19072
#
#                            Area Name Society        Facing Type of Property  \
# 3                        Kalyan West       Y          East        Apartment
# ...

# %%
# Remove outliers for 'Price' using IQR
Q1_Price = main['Price'].quantile(0.25)
Q3_Price= main['Price'].quantile(0.75)
IQR_Price = Q3_Price - Q1_Price
lower_bound_Price = Q1_Price - 1.5 * IQR_Price
upper_bound_Price = Q3_Price + 1.5 * IQR_Price

main = main[(main['Price'] >= lower_bound_Price) & (main['Price'] <= upper_bound_Price)]

# Verify the number of outliers in 'Price' after removal
outliers_main_cleaned = count_outliers_iqr(main, 'Price')

print(f"Number of outliers in 'Price' after removal: {outliers_main_cleaned}")
# Out:
# Number of outliers in 'Price' after removal: 0

# %%
# Remove outliers for 'sqft Price ' using IQR
Q1_sqft_Price  = main['sqft Price '].quantile(0.25)
Q3_sqft_Price = main['sqft Price '].quantile(0.75)
IQR_sqft_Price = Q3_sqft_Price - Q1_sqft_Price
lower_bound_sqft_Price= Q1_sqft_Price - 1.5 * IQR_sqft_Price
upper_bound_sqft_Price = Q3_sqft_Price+ 1.5 * IQR_sqft_Price

main = main[(main['sqft Price '] >= lower_bound_sqft_Price) & (main['sqft Price '] <= upper_bound_sqft_Price)]

# Verify the number of outliers in 'sqft Price ' after removal
outliers_main_cleaned = count_outliers_iqr(main, 'sqft Price ')
print(f"Number of outliers in 'sqft Price ' after removal: {outliers_main_cleaned}")
# Out:
# Number of outliers in 'sqft Price ' after removal: 0

# %%
main
# Out:
#           ID Floor No Commercial           Developer  sqft Price   \
# 3      12682        5          N       Birla Estates         8571
# 5      12680       16          N       Tycoons Group         6157
# 8      12677       16          N   Godrej Properties         5826
# 14     12671       16          N     Gurukrupa Group         6763
# 17     12668        9          N     Gurukrupa Group         7608
# ...      ...      ...        ...                 ...          ...
# 12655     30       10          N   Anchor Properties        12666
# 12660     25        5          N  Oberoi Realty Ltd.        30864
# 12662     23        4          N      Sheth Creators        17049
# 12681      4       10          N      Kalpataru Ltd.        22529
# 12682      3        5          N      Kalpataru Ltd.        19072
#
#                            Area Name Society        Facing Type of Property  \
# 3                        Kalyan West       Y          East        Apartment
# ...

# %%
main.isna().sum()
# Out:
# ID                   0
# Floor No            44
# Commercial           0
# Developer            0
# sqft Price           0
# Area Name            0
# Society              0
# Facing               0
# Type of Property     0
# City                 0
# furnished Type       0
# Location             0
# balconies            0
# Sea facing           0
# Price                0
# SQFT_AREA           17
# dtype: int64

# %%
main
# Out:
#           ID Floor No Commercial           Developer  sqft Price   \
# 3      12682        5          N       Birla Estates         8571
# 5      12680       16          N       Tycoons Group         6157
# 8      12677       16          N   Godrej Properties         5826
# 14     12671       16          N     Gurukrupa Group         6763
# 17     12668        9          N     Gurukrupa Group         7608
# ...      ...      ...        ...                 ...          ...
# 12655     30       10          N   Anchor Properties        12666
# 12660     25        5          N  Oberoi Realty Ltd.        30864
# 12662     23        4          N      Sheth Creators        17049
# 12681      4       10          N      Kalpataru Ltd.        22529
# 12682      3        5          N      Kalpataru Ltd.        19072
#
#                            Area Name Society        Facing Type of Property  \
# 3                        Kalyan West       Y          East        Apartment
# ...

# %%
main.drop('SQFT_AREA',axis=1,inplace=True)

# %%
main['Price'].replace(0,np.nan,inplace=True)
# Out:
# /tmp/ipython-input-410579070.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   main['Price'].replace(0,np.nan,inplace=True)

# %%
main.isna().sum()
# Out:
# ID                   0
# Floor No            44
# Commercial           0
# Developer            0
# sqft Price           0
# Area Name            0
# Society              0
# Facing               0
# Type of Property     0
# City                 0
# furnished Type       0
# Location             0
# balconies            0
# Sea facing           0
# Price               17
# dtype: int64

# %%
main.dropna(subset=['sqft Price '],inplace=True)

# %%
main.dropna(subset=['Price'],inplace=True)

# %%
main.isna().sum()
# Out:
# ID                   0
# Floor No            44
# Commercial           0
# Developer            0
# sqft Price           0
# Area Name            0
# Society              0
# Facing               0
# Type of Property     0
# City                 0
# furnished Type       0
# Location             0
# balconies            0
# Sea facing           0
# Price                0
# dtype: int64

# %%
(main['Price'] > 35000000).sum()
# Out:
# np.int64(118)

# %%
main['SQFT_AREA']=main['Price']/main['sqft Price ']

# %%
main['sqft Price '].replace(0,np.nan)
# Out:
# 3        8571.00
# 5        6157.00
# 8        5826.00
# 14       6763.00
# 17       7608.00
#           ...
# 12655   12666.00
# 12660   30864.00
# 12662   17049.00
# 12681   22529.00
# 12682   19072.00
# Name: sqft Price , Length: 2711, dtype: float64

# %%
main['Facing'].unique()
# Out:
# array(['East', 'North - East', 'North - West', 'Visit & See', 'West',
#        'North', 'South - East', 'South', 'South -West'], dtype=object)

# %%
main['SQFT_AREA'].replace(np.inf,np.nan,inplace=True)
# Out:
# /tmp/ipython-input-2945086571.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   main['SQFT_AREA'].replace(np.inf,np.nan,inplace=True)

# %%
inf_count = main[main['SQFT_AREA'] == np.inf].shape[0]
print(f"Number of infinite values in 'SQFT_AREA': {inf_count}")
# Out:
# Number of infinite values in 'SQFT_AREA': 0

# %%
main.dropna(subset=["SQFT_AREA"],inplace=True)

# %%
main.dropna(subset=['Floor No'],inplace=True)

# %%
main.isna().sum()
# Out:
# ID                  0
# Floor No            0
# Commercial          0
# Developer           0
# sqft Price          0
# Area Name           0
# Society             0
# Facing              0
# Type of Property    0
# City                0
# furnished Type      0
# Location            0
# balconies           0
# Sea facing          0
# Price               0
# SQFT_AREA           0
# dtype: int64

# %%
# # Remove duplicates while ignoring 'ID' column
# main = main.drop_duplicates(subset=main.columns.difference(['ID']), keep='first').reset_index(drop=True)

# # Show how many rows are left after cleaning
# print("Rows after removing duplicates:", len(main))

# %%
from sklearn.model_selection import train_test_split

# Split data into 80% and 20%
main_80, main_20 = train_test_split(main, test_size=0.2, random_state=42)

# Save the 20% split to a new CSV file
main_20.to_csv("main_properties_20.csv", index=False)

print("Data split into 80% and 20%.")
print("20% data saved to 'india_properties_20.csv'")
# Out:
# Data split into 80% and 20%.
# 20% data saved to 'india_properties_20.csv'

# %%
main_20.to_csv("main_20_price",index=False)

# %%
main_20.drop('Price',axis=1,inplace=True,)

# %%
main_20.drop('sqft Price ',axis=1,inplace=True)

# %%
main_20.to_csv('main_20',index=False)

# %%
main_80.to_csv("main_80",index=False)

# %%
main_80
# Out:
#           ID Floor No Commercial                        Developer  \
# 1959   10726        4          N                       Eric Group
# 11456   1229        5          N                        Rustomjee
# 6282    6403        9          Y           MAA ASHAPURA DEVLOPERS
# 1375   11310       11          Y                    Regency Group
# 4644    8041        5          Y               Ashwin Sheth Group
# ...      ...      ...        ...                              ...
# 7481    5204        9          N                 Raj Realty Group
# 4700    7985        6          N                            Lodha
# 4986    7699        5          N   Shakti Builders and Developers
# 5622    7063       19          N                   Piramal Realty
# 4099    8586        1          N  Kanakia Spaces Realty Pvt. Ltd.
#
#        sqft Price        Area Name Society       Facing Type of Property  \
# 1959          4285      Virar West       Y         East        Apartment
# ...

# %%
# %pip install catboost

# %%
import pandas as pd
from catboost import CatBoostRegressor, Pool
from sklearn.metrics import r2_score, mean_squared_error
import numpy as np

# Load data
df = pd.read_csv('/content/main_80')

# # ✅ Remove unnecessary index column if present
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]

# Separate features and target
X = df.drop(['Price','sqft Price ','Facing','Area Name','Location','Commercial','balconies','furnished Type'], axis=1)
y = df['Price']

# Identify categorical columns (non-numeric)
cat_features = X.select_dtypes(include=['object']).columns.tolist()
print("Categorical features:", cat_features)

# Fill NaN values in categorical columns with a placeholder
for col in cat_features:
    X[col] = X[col].fillna('Unknown')


# Create CatBoost Pool (handles categorical columns automatically)
train_pool = Pool(data=X, label=y, cat_features=cat_features)

# Initialize and train CatBoost model
model = CatBoostRegressor(
    iterations=10000,
    learning_rate=0.03,
    depth=9,
    loss_function='RMSE', # RMSE is suitable for log-transformed target
    random_seed=42,
    verbose=200
)

model.fit(train_pool)

# Save model
model.save_model('catboost_main_model.cbm')
print("✅ Model trained successfully and saved!")

print("Numeric features used:", X.select_dtypes(include=[np.number]).columns.tolist())
# Out:
# Categorical features: ['Developer', 'Society', 'Type of Property', 'City']
# 0:	learn: 9643651.2436575	total: 29.3ms	remaining: 4m 53s
# 200:	learn: 3304479.5378603	total: 2.48s	remaining: 2m
# 400:	learn: 2705593.2732246	total: 4.45s	remaining: 1m 46s
# 600:	learn: 2309334.0524547	total: 5.6s	remaining: 1m 27s
# 800:	learn: 2008174.8411749	total: 6.87s	remaining: 1m 18s
# 1000:	learn: 1771432.9411848	total: 8.65s	remaining: 1m 17s
# 1200:	learn: 1579177.9616137	total: 9.77s	remaining: 1m 11s
# 1400:	learn: 1415198.0055475	total: 11s	remaining: 1m 7s
# 1600:	learn: 1279686.3283066	total: 12.2s	remaining: 1m 4s
# 1800:	learn: 1171077.4115830	total: 13.4s	remaining: 1m 1s
# 2000:	learn: 1075746.7886503	total: 14.6s	remaining: 58.4s
# 2200:	learn: 990328.2513319	total: 15.8s	remaining: 56s
# 2400:	learn: 917628.0020443	total: 16.9s	remaining: 53.6s
# 2600:	learn: 846733.7816849	total: 18.1s	remaining: 51.6s
# 2800:	learn: 786332.1655937	total: 20s	remaining: 51.4s
# ...

# %%
import pandas as pd
import numpy as np
from catboost import CatBoostRegressor, Pool

# Paths (adjust if your filenames differ)
train_path = '/content/main_80'
test_path = '/content/main_20'
model_path = '/content/catboost_main_model.cbm'

# Load training data to get schema
train_df = pd.read_csv(train_path)
expected_features = [c for c in train_df.columns if c != 'Price']

# Detect categorical columns from training data
cat_features = train_df[expected_features].select_dtypes(include=['object']).columns.tolist()
print("Categorical features:", cat_features)

# Load trained CatBoost model
model = CatBoostRegressor()
model.load_model(model_path)

# Load test data (without price)
test_df = pd.read_csv(test_path).copy()

# Make sure the test data has same columns as training data
for col in expected_features:
    if col not in test_df.columns:
        test_df[col] = np.nan

# Reorder columns to match training
X_test = test_df[expected_features]

# Convert categorical features to string type
for c in cat_features:
    X_test[c] = X_test[c].astype(str)

# Create Pool for CatBoost
test_pool = Pool(data=X_test, cat_features=cat_features)

# Predict prices
predictions = model.predict(test_pool)

# Add predictions to your test dataframe
test_df['PREDICTED_Price'] = predictions

# Save new CSV with predictions
output_path = '/content/main_20_with_predicted_price.csv'
test_df.to_csv(output_path, index=False)

print("✅ Prediction complete! File saved as:", output_path)

# Display predictions in full number format
pd.options.display.float_format = '{:.2f}'.format

display(test_df[['PREDICTED_Price']].head())
# Out:
# Categorical features: ['Commercial', 'Developer', 'Area Name', 'Society', 'Facing', 'Type of Property', 'City', 'furnished Type', 'Location']
# ✅ Prediction complete! File saved as: /content/main_20_with_predicted_price.csv
#    PREDICTED_Price
# 0      17717468.22
# 1       4180055.28
# 2      11912406.41
# 3      15888670.85
# 4       5160907.36

# %%
import pandas as pd
from sklearn.metrics import r2_score, mean_squared_error
import numpy as np

# Paths (adjust if needed)
pred_path = '/content/main_20_with_predicted_price.csv'
actual_path = '/content/main_20_price'

# Load both CSVs
pred_df = pd.read_csv(pred_path)
actual_df = pd.read_csv(actual_path)

# Merge on common columns (like property ID or other shared keys)
# If both files have identical row order, you can merge by index instead
combined = pd.merge(actual_df, pred_df[['ID', 'PREDICTED_Price']], on='ID', how='inner')

# Calculate metrics
r2 = r2_score(combined['Price'], combined['PREDICTED_Price'])
rmse = np.sqrt(mean_squared_error(combined['Price'], combined['PREDICTED_Price']))

print(f"R-squared (Accuracy): {r2:.4f}")
print(f"Root Mean Squared Error (RMSE): {rmse:,.2f}")

# Optional: display first few comparisons
comparison = combined[['Price', 'PREDICTED_Price']].head(10)
print("\nSample comparison:")
print(comparison)
# Out:
# R-squared (Accuracy): 0.8853
# Root Mean Squared Error (RMSE): 3,512,591.42
#
# Sample comparison:
#         Price  PREDICTED_Price
# 0 15000000.00      17717468.22
# 1  3900000.00       4180055.28
# 2 11000000.00      11912406.41
# 3 13500000.00      15888670.85
# 4  4200000.00       5160907.36
# 5 12700000.00      11983895.03
# 6 37000000.00      37246144.16
# 7  6757000.00       5668015.65
# 8 20500000.00      19186286.41
# 9 14500000.00      16322580.94
